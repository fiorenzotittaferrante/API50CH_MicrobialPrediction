# %% [markdown]
# # Download of the dataset
#
# This notebook is used to to download the BacDive dataset. It is also available a .py version, useful to call the `download()` function externally.

# %%
import os
import sys
import glob
import pandas
import time
import fnmatch
import gzip
import shutil
import ftplib
import numpy as np

from ftplib import FTP, error_perm

# %% [markdown]
# There are four mainly functions:
#  * `prepare`: from some xlsx (specified in ifolder) it can retrieve the names of the files to download.
#  * `download_ncbi_from_ftp`: given the genomes, the url, the suffix of the file (fna or gff) and a path, it downloads the files.
#  * `download_patric_from_ftp`: download other files in a slightly different way.
#  * `unpack_ncbi`: unpack the downloaded files using gzip.
#  * `prepare_aflp_silco`: run the AFLP software and generate the .wri files.

# %% [markdown]
# ## Functions

# %%
def prepare():
    ifolder = '../Data/configuration/'
    files_name = sorted([os.path.basename(f).replace('.xlsx', '') for f in glob.glob(ifolder + "*.xlsx")])

    print("Preparing the download...")
    print("Custom download files:", f"\n{files_name}")
    
    if not os.path.exists('../Data/BacDive/'):
        os.makedirs('../Data/BacDive/')    
    
    frames = []

    for file_name in files_name:

        file = pandas.read_excel(open(ifolder+file_name+'.xlsx', 'rb'),header=None) 

        file.columns = file.loc[9,:]
        file.dropna(axis=0, how='all', inplace=True)
        file.drop(file[(file['strains.Culture collection no.'].str.contains('http', na=False)) | 
                       (file['strains.Culture collection no.'] == 'URL')].index, inplace = True)
        file.drop(file[file['strains.ID_strains'] == 'References'].index, inplace = True)
        file.drop(file.head(5).index,inplace=True)
        file.drop(file.tail(1).index,inplace=True)
        file.drop(index=file.index[0], axis=0, inplace=True)

        file.to_excel('../Data/BacDive/'+file_name+'.xlsx',index=None)

        file_50CH = file.loc[file['kit_api_50CHac.ID_reference'] > 0]
        file_50CH = file_50CH.iloc[:, np.r_[0:12,152:203]]
        frames.append(file_50CH)

    result_file_50CH = pandas.concat(frames)
    result_file_50CH.to_excel('../Data/BacDive/Genome_50CH_ac.xlsx',index=None)

    result_file_50CH = result_file_50CH.replace(['-', '+', '+/-'], [0,1,0])
    result_file_50CH.to_excel('../Data/BacDive/Genome_50CH_ac_0_1.xlsx',index=None)
    
    print("** Generated files Genome_50CH_ac.xlsx and Genome_50CH_ac_0_1.xlsx into Data/BacDive/ folder. \n")
    
    genome_ncbi = result_file_50CH.loc[result_file_50CH['sequence_genomes.Sequence database'] == 'ncbi']
    sequence_genomes_ncbi = list(set(genome_ncbi['sequence_genomes.Seq. accession number']))
    
    genome_patric = result_file_50CH.loc[result_file_50CH['sequence_genomes.Sequence database'] == 'patric']
    sequence_genomes_patric = list(set(genome_patric['sequence_genomes.Seq. accession number']))
    
    return genome_ncbi, sequence_genomes_ncbi, genome_patric, sequence_genomes_patric 



def unpack_ncbi(folder_ncbi, files_name_ncbi, file_type):
    print(f"\nUnzip files in {folder_ncbi}...")
    decompress_folder = os.path.join(folder_ncbi, 'Decompress')
    
    if not os.path.exists(decompress_folder):
        os.makedirs(decompress_folder)

    for file in files_name_ncbi:
        input_file_path = os.path.join(folder_ncbi, file + file_type + '.gz')
        output_file_path = os.path.join(decompress_folder, file + file_type)

        with gzip.open(input_file_path, 'rb') as f_in:
            with open(output_file_path, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)
                
    print("Done!")

# %%
def download_ncbi_from_ftp(sequence_genomes, url_prefix, file_suffix, download_path):
    tic = time.perf_counter()

    ftp = ftplib.FTP('ftp.ncbi.nlm.nih.gov')
    ftp.login()
    
    if not os.path.exists(download_path):
        os.makedirs(download_path)
        
    for sequence in sequence_genomes:
                
        toc = time.perf_counter()

        if toc - tic >= 200:
            ftp.quit()
            ftp = ftplib.FTP('ftp.ncbi.nlm.nih.gov')
            ftp.login()

            tic = time.perf_counter()

        url = url_prefix

        if sequence[0:3] == 'GCA':
            for index in range(4, len(sequence), 3):
                url = url + sequence[index:(index + 3)] + '/'

        ftp.cwd(url)
        name = next(iter(ftp.nlst()))
        ftp.cwd(name)

        files = ftp.nlst()
                        
        if not any(file_suffix in string for string in files):
            print(f'  File {sequence} not found in GCA. Trying to find the .gff in GCF folder.')
            url = url[:12] + 'GCF' + url[15:]
            
            ftp.cwd('/.')
            try:
                ftp.cwd(url)
            except error_perm as e:
                if "550" in str(e):
                    print("")
                    print("="*80)
                    print(f"{url}: No such file or directory")
                    print("="*80,"\n")     
                else:
                    return " other error."
                    
            name = next(iter(ftp.nlst()))
            ftp.cwd(name)

            files = ftp.nlst()         
            
        # Download files
        for file in files:

            if fnmatch.fnmatch(file, name + file_suffix):  # To download specific files.

                if file[0:3] == 'GCF': # Change file name from GCF_* to GCA_*.
                    file_path = os.path.join(download_path, 'GCA' + file[3:])
                else:
                    file_path = os.path.join(download_path, file)
                

                if not os.path.exists(file_path):

                    try:
                        ftp.retrbinary("RETR " + file, open(file_path, 'wb').write)

                    except EOFError:  # To avoid EOF errors.
                        pass
                else:
                    print(f"  File already exists: {file_path}")            
                

        ftp.cwd('/.')

    ftp.quit()
    
    print(f"Files downloaded in {download_path}")

# %%
def download_patric_from_ftp(sequence_genomes, url_prefix, file_suffix, download_path):
    tic = time.perf_counter()

    ftp = ftplib.FTP('ftp.bvbrc.org')
    ftp.login()
    
    if not os.path.exists(download_path):
        os.makedirs(download_path)

    # Unable to download entire sequence: "no file or directory" error when searching for data online.
    sequence_error = [525325.5, 1589.1, 1589.9, 1226298.1, 'GCA_001475175', 219334.1, 391904.2, 1358.133, 51663.5, 1423723.1, 273384.3, 518634.2]
    
    for sequence in sequence_genomes:

        toc = time.perf_counter()

        if toc - tic >= 200:
            ftp.quit()
            ftp = ftplib.FTP('ftp.bvbrc.org')
            ftp.login()

            tic = time.perf_counter()

        if sequence in sequence_error:
            print(f'  *** Strain {sequence} not downloaded: file not found online. ***\n')

        else:
            url = url_prefix + str(sequence) + '/'
            ftp.cwd(url)

            file_name = str(sequence) + file_suffix

            files = ftp.nlst()

            # Download files
            for file in files:
                if fnmatch.fnmatch(file, file_name):  # To download specific files.
                    file_path = os.path.join(download_path, file)
                    
                    if not os.path.exists(file_path):

                        try:
                            ftp.retrbinary("RETR " + file, open(file_path, 'wb').write)

                        except EOFError:  # To avoid EOF errors.
                            pass
                    else:
                        print(f"  File already exists: {file_path}")

            ftp.cwd('/.')

    ftp.quit()
  
    print(f"Files downloaded in {download_path}\n")

# %% [markdown]
# ## Download files

# %%
def download(genome_ncbi, sequence_genomes_ncbi, genome_patric, sequence_genomes_patric):
    url_prefix = 'genomes/all/GCA/'
    file_suffix_fna = '_genomic.fna.gz'
    download_path_fna = '../Data/BacDive/ncbi/'
    file_type_fna = '.fna'

    file_suffix_gff = '_genomic.gff.gz'
    download_path_gff = '../Data/BacDive/gff/ncbi/'
    file_type_gff = '.gff'

    patric_url_prefix_fna = 'genomes/'
    patric_file_suffix_fna = '.fna'
    patric_download_path_fna = '../Data/BacDive/Patric/'

    patric_url_prefix_gff = 'genomes/'
    patric_file_suffix_gff = '.PATRIC.gff'
    patric_download_path_gff = '../Data/BacDive/gff/Patric/'

    paths = pandas.Series([download_path_fna, download_path_gff, patric_download_path_fna, patric_download_path_gff])

    for path in paths:
        if not os.path.exists(path):
            os.makedirs(path)


    try:
        print("\nDownloading ncbi fna files...")
        download_ncbi_from_ftp(sequence_genomes_ncbi, url_prefix, file_suffix_fna, download_path_fna)

        print("\nDownloading ncbi gff files... (Problemi)")
        download_ncbi_from_ftp(sequence_genomes_ncbi, url_prefix, file_suffix_gff, download_path_gff)
        
        print("\nDownloading Patric fna files...")
        download_patric_from_ftp(sequence_genomes_patric, patric_url_prefix_fna, patric_file_suffix_fna, patric_download_path_fna)
        
        print("\nDownloading Patric gff files...")
        download_patric_from_ftp(sequence_genomes_patric, patric_url_prefix_gff, patric_file_suffix_gff, patric_download_path_gff)

    except Exception as e:
        print("="*80)
        print(f"Errore: {e}")
        print("="*80)
        print('\n')
        
        
    files_name_ncbi_fna = sorted([f.replace('.fna.gz', '').replace(download_path_fna, '').replace(download_path_fna, '') for f in glob.glob(download_path_fna + "*.fna.gz")])
    files_name_ncbi_gff = sorted([f.replace('.gff.gz', '').replace(download_path_gff, '').replace(download_path_gff, '') for f in glob.glob(download_path_gff + "*.gff.gz")])

    unpack_ncbi(download_path_fna, files_name_ncbi_fna, file_type_fna)
    unpack_ncbi(download_path_gff, files_name_ncbi_gff, file_type_gff)

# %%
genome_ncbi, sequence_genomes_ncbi, genome_patric, sequence_genomes_patric = prepare() # Prepare all the files to download

download(genome_ncbi, sequence_genomes_ncbi, genome_patric, sequence_genomes_patric)
# Out:
# Downloading ncbi fna files...
#
# Downloading ncbi gff files... (Problemi)
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007992275.1_ASM799227v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001025155.1_ASM102515v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_019753765.1_ASM1975376v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_009764355.1_ASM976435v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_018314255.1_ASM1831425v1_genomic.gff.gz
#   File GCA_010120595 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_010120595.1_ASM1012059v1_genomic.gff.gz
#   File GCA_000374385 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000374385.1_ASM37438v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001025175.1_ASM102517v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_017874575.1_ASM1787457v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014898155.1_ASM1489815v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_019586025.1_ASM1958602v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014207505.1_ASM1420750v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002706705.1_ASM270670v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_009764365.1_L._kimchii_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_023657385.1_ASM2365738v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900079995.1_ASM90007999v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003697165.1_ASM369716v1_genomic.gff.gz
#   File GCA_902833925 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_902833925.1_ASM90283392v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000024285.1_ASM2428v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000829035.1_ASM82903v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001050115.1_ASM105011v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003641145.1_ASM364114v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002095475.1_ASM209547v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900015005.1_Lactobacillus_oligofermentans_LMG_22743_genome_genomic.gff.gz
#   File GCA_001311115 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001311115.1_ASM131111v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000469365.1_ASM46936v1_genomic.gff.gz
#   File GCA_000427785 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000427785.1_ASM42778v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_009727155.1_ASM972715v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001042695.1_ASM104269v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001274725.1_ASM127472v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002706375.1_ASM270637v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_009299505.1_ASM929950v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000829055.1_ASM82905v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_018717645.1_ASM1871764v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001888925.1_ASM188892v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014648715.1_ASM1464871v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007991135.1_ASM799113v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000196555.1_ASM19655v1_genomic.gff.gz
#   File GCA_000744825 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000744825.1_ASM74482v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002907375.1_ASM290737v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001025195.1_ASM102519v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007992235.1_ASM799223v1_genomic.gff.gz
#   File GCA_019655995 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_019655995.1_ASM1965599v1_genomic.gff.gz
#   File GCA_001591685 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001591685.1_ASM159168v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000829395.1_ASM82939v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900637145.1_49569_E01_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001047135.1_ASM104713v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_008326545.1_ASM832654v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001888965.1_ASM188896v1_genomic.gff.gz
#   File GCA_000425865 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000425865.1_ASM42586v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000160855.1_ASM16085v1_genomic.gff.gz
#   File GCA_000615725 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000615725.1_ASM61572v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000163475.1_ASM16347v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014635685.1_ASM1463568v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_023657365.1_ASM2365736v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900637335.1_50618_H02_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900089835.1_VthalassaeCECT8203_Velvet_Prokka_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900103055.1_IMG-taxon_2636416037_annotated_assembly_genomic.gff.gz
#   File GCA_000615245 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000615245.1_ASM61524v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000014425.1_ASM1442v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002370355.1_ASM237035v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001047695.1_ASM104769v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007991875.1_ASM799187v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002259645.1_ASM225964v1_genomic.gff.gz
#   File GCA_905371965 not found in GCA. Trying to find the .gff in GCF folder.
# ================================================================================
# genomes/all/GCF/905/371/965/: No such file or directory
# ================================================================================
#
#   File GCA_019656055 not found in GCA. Trying to find the .gff in GCF folder.
#   File GCA_019656015 not found in GCA. Trying to find the .gff in GCF folder.
#   File GCA_001591885 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003795105.1_ASM379510v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_018094625.1_ASM1809462v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_009299485.1_ASM929948v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001433985.1_ASM143398v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900637175.1_49569_F01_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002811195.1_ASM281119v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014646835.1_ASM1464683v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002217925.1_ASM221792v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002849895.1_ASM284989v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014651215.1_ASM1465121v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_017132775.1_ASM1713277v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001025215.1_ASM102521v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900187315.1_52087_C01_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014651255.1_ASM1465125v1_genomic.gff.gz
#   File GCA_003946245 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014467235.1_ASM1446723v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_016908715.1_ASM1690871v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900167245.1_IMG-taxon_2568526012_annotated_assembly_genomic.gff.gz
#   File GCA_003946275 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003946275.1_ASM394627v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_020089505.1_ASM2008950v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_012103035.1_O.oryzae_NBRC_102588.fasta_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003641185.1_ASM364118v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000296855.1_ASM29685v1_genomic.gff.gz
#   File GCA_019656075 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_017654245.1_ASM1765424v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_018987235.1_ASM1898723v1_genomic.gff.gz
#   File GCA_001311505 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001436025.1_ASM143602v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000706765.1_ASM70676v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003423665.1_ASM342366v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000876205.1_ASM87620v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000056065.1_ASM5606v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000498955.1_DSM-21115_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_019444005.1_ASM1944400v1_genomic.gff.gz
#   File GCA_001313225 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000632805.1_ASM63280v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000196855.1_ASM19685v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007990205.1_ASM799020v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001437255.1_ASM143725v1_genomic.gff.gz
#   File GCA_000185065 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000831645.1_ASM83164v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001465545.1_ASM146554v1_genomic.gff.gz
#   File GCA_000615325 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000615325.1_ASM61532v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001908495.1_ASM190849v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_004209755.1_ASM420975v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_013394085.1_ASM1339408v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000737845.1_BBOMBassembly_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014191315.1_ASM1419131v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001042615.1_ASM104261v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_004322755.1_ASM432275v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900476045.1_50279_D01_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900637095.1_48450_G02_genomic.gff.gz
#   File GCA_900324475 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900324475.1_EB-247_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000269965.1_ASM26996v1_genomic.gff.gz
#   File GCA_000426405 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000426405.1_ASM42640v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007990855.1_ASM799085v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003096575.1_ASM309657v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014651415.1_ASM1465141v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_017298735.1_ASM1729873v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007989165.1_ASM798916v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003047065.1_ASM304706v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002706745.1_ASM270674v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000010425.1_ASM1042v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007989145.1_ASM798914v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900187025.1_49923_F01_genomic.gff.gz
#   File GCA_000744255 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002015125.1_ASM201512v1_genomic.gff.gz
#   File GCA_019655915 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001263395.1_ASM126339v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002706665.1_ASM270666v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000967195.1_ASM96719v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002736025.1_ASM273602v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002259755.1_ASM225975v1_genomic.gff.gz
#   File GCA_014634745 not found in GCA. Trying to find the .gff in GCF folder.
#   File GCA_003946015 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003946015.1_ASM394601v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002259705.1_ASM225970v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002706425.1_ASM270642v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002259605.1_ASM225960v1_genomic.gff.gz
#   File GCA_000615405 not found in GCA. Trying to find the .gff in GCF folder.
#   File GCA_000429585 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900186835.1_49950_F01_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_901212485.1_NZ_Bifidobacterium_bifidum_MC1_genomic.gff.gz
#   File GCA_000771045 not found in GCA. Trying to find the .gff in GCF folder.
#   File GCA_002916915 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002916915.1_ASM291691v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000014445.1_ASM1444v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000008565.1_ASM856v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007989125.1_ASM798912v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900478165.1_48290_A02_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_009299475.1_ASM929947v1_genomic.gff.gz
#   File GCA_000423725 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001437285.1_ASM143728v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_004362535.1_ASM436253v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001025135.1_ASM102513v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000020425.1_ASM2042v1_genomic.gff.gz
#   File GCA_000166715 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002259745.1_ASM225974v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014651235.1_ASM1465123v1_genomic.gff.gz
#   File GCA_001039045 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001543205.1_ASM154320v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001908415.1_ASM190841v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003641165.1_ASM364116v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_009495475.1_ASM949547v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002278095.1_ASM227809v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000010005.1_ASM1000v1_genomic.gff.gz
#   File GCA_905371805 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_905371805.1_SRR9217392-mag-bin.4_genomic.gff.gz
#   File GCA_005405505 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000241055.1_ASM24105v1_genomic.gff.gz
#   File GCA_000615205 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014898175.1_ASM1489817v1_genomic.gff.gz
#   File GCA_001311335 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001311335.1_ASM131133v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_004101845.1_ASM410184v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001042675.1_ASM104267v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900637215.1_49888_B01_genomic.gff.gz
#   File GCA_001311525 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001311525.1_ASM131152v1_genomic.gff.gz
#   File GCA_002607735 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000260715.1_ASM26071v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_003369815.1_ASM336981v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900103655.1_IMG-taxon_2597490363_annotated_assembly_genomic.gff.gz
#   File GCA_001592085 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_012396505.1_ASM1239650v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014131735.1_ASM1413173v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007991995.1_ASM799199v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_009764345.1_ASM976434v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007991295.1_ASM799129v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007989185.1_ASM798918v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001436135.1_ASM143613v1_genomic.gff.gz
#   File GCA_000771085 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007991855.1_ASM799185v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001434175.1_ASM143417v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900187015.1_50465_F01_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_017299435.1_ASM1729943v1_genomic.gff.gz
#   File GCA_019655935 not found in GCA. Trying to find the .gff in GCF folder.
#   File GCA_005405645 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000146325.1_ASM14632v1_genomic.gff.gz
#   File GCA_005405385 not found in GCA. Trying to find the .gff in GCF folder.
#   File GCA_002777965 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_015698225.1_ASM1569822v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014651435.1_ASM1465143v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_007992315.1_ASM799231v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001042635.1_ASM104263v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_016908275.1_ASM1690827v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_014635905.1_ASM1463590v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001281175.1_ASM128117v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002907365.1_ASM290736v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000016825.1_ASM1682v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001936335.1_ASM193633v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001891125.1_ASM189112v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_900099625.1_IMG-taxon_2597490350_annotated_assembly_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_017132755.1_ASM1713275v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000143745.1_ASM14374v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_002802875.1_Spades_TRE1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_019443985.1_ASM1944398v1_genomic.gff.gz
#   File GCA_000745125 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000745125.1_ASM74512v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000970855.1_ASM97085v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_017086525.1_ASM1708652v1_genomic.gff.gz
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_001436735.1_ASM143673v1_genomic.gff.gz
#   File GCA_000423745 not found in GCA. Trying to find the .gff in GCF folder.
#   File already exists: ../Data/BacDive/gff/ncbi/GCA_000423745.1_ASM42374v1_genomic.gff.gz
# Files downloaded in ../Data/BacDive/gff/ncbi/
# -1

# %% [markdown]
# ## Check missing files

# %%
folder1 = '../Data/BacDive/ncbi/Decompress/'
folder2 = '../Data/BacDive/gff/ncbi/Decompress/'

files1 = [os.path.splitext(f)[0][:-4] for f in os.listdir(folder1) if os.path.isfile(os.path.join(folder1, f))]
files2 = [os.path.splitext(f)[0][:-4] for f in os.listdir(folder2) if os.path.isfile(os.path.join(folder2, f))]

unique_files_in_folder1 = set(files1) - set(files2)
unique_files_in_folder2 = set(files2) - set(files1)

print(f"Nomi di file presenti solo nella cartella {folder1}:")
for filename in unique_files_in_folder1:
    print(filename)
    
print('\n\n')
print(f"Nomi di file presenti solo nella cartella {folder2}:")
for filename in unique_files_in_folder2:
    print(filename)
# Out:
# Nomi di file presenti solo nella cartella ../Data/BacDive/ncbi/Decompress/:
# GCA_000185065.2_ASM18506v1_gen
# GCA_905371965.1_SRR9217392-mag-bin.15_gen
# GCA_000166715.2_ASM16671v1_gen
#
#
#
# Nomi di file presenti solo nella cartella ../Data/BacDive/gff/ncbi/Decompress/:
# GCA_000166715.1_ASM16671v1_gen
# GCA_000185065.1_ASM18506v1_gen

# %% [markdown]
# # Generate the dataset

# %%
def prepare_aflp_silco():
    os.chdir('AFLPinSilico')
    folder = '../../Data/BacDive/AFLP_perl/'

    if not os.path.exists(folder):
        os.makedirs(folder)

    # !cpan CGI -y # In case the CGI module is not installed

    if sys.platform.startswith('win'):
        perl_script = 'script_AFLP_perl.pl'
    elif sys.platform.startswith('darwin') or sys.platform.startswith('linux'):
        perl_script = 'script_AFLP_perl_UNIX.pl'
    else:
        print("Operative System not supported.")
        sys.exit(1)

    os.system(f"perl {perl_script}")

    files_name = sorted([os.path.basename(f).replace('.wri', '') for f in glob.glob(folder + '*.wri')])
    
    os.chdir('..')
    
    return files_name




def generate_dataset(files_name):
    folder = '../Data/BacDive/AFLP_perl/'
    
    aflp_int = list()
    file_col = list()

    for file in files_name:

        file_col.append(file[:13])
        aflp_int_row = list()

        aflp_50_500 = pandas.read_table(folder+file+'.wri', header=10)
        aflp_50_500.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)
        aflp_50_500 = aflp_50_500.loc[(aflp_50_500['FragLength'] >= 50) & (aflp_50_500['FragLength'] <= 500)]

        freq = aflp_50_500['FragLength'].value_counts()
        frag_length = freq.sort_index()
        frag_length_index = frag_length.index

        for f in range(50,501,1):
            if f in frag_length_index:
                aflp_int_row.append(freq[f])
            else:
                aflp_int_row.append(0)

        aflp_int.append(aflp_int_row)

    aflp_int_df = pandas.DataFrame(aflp_int)
    aflp_int_df.columns = list(range(50, 501))
    aflp_int_df['sequence_genomes.Seq. accession number'] = file_col
    aflp_int_df.to_excel('../Data/BacDive/aflp_int_AFLPinSilco.xlsx',index=False)
    
    # Reads the original dataset to eliminate superfluous information, set the indexes and to do some checks.
    X = pandas.read_excel("../Data/BacDive/aflp_int_AFLPinSilco.xlsx")
    y = pandas.read_excel("../Data/BacDive/Genome_50CH_ac_0_1.xlsx")

    X['sequence_genomes.Seq. accession number'] = X['sequence_genomes.Seq. accession number'].astype(str)
    y['sequence_genomes.Seq. accession number'] = target['sequence_genomes.Seq. accession number'].astype(str) 

    X = X.rename(columns={'sequence_genomes.Seq. accession number': 'strain'}).set_index('strain').sort_index()
    y = y.rename(columns={'sequence_genomes.Seq. accession number': 'strain'}).set_index('strain').sort_index()

    y = y.iloc[:, list(range(11, 61))]
    y = y.loc[X.index]

    for i in range(len(X.index)):
        if X.index[i] != y.index[i]:
            print(f"The row indices in row {i} are not equal: {X.index[i]} vs {y.index[i]}")

    with pandas.ExcelWriter('../Data/X.xlsx') as writer:
        X.to_excel(writer, index=True)

    with pandas.ExcelWriter('../Data/Y.xlsx') as writer:
        y.to_excel(writer, index=True)
        
    print("\n\nDataset saved in Data/X.xlsx and in Data/Y.xlsx")
    
    display(X)
    display(y)

    
    
files_name = prepare_aflp_silco()
generate_dataset(files_name)
# Out:
# GCA_001025135.1_ASM102513v1_genomic
# selectiv5 	selectiv3
# GCA_023657385.1_ASM2365738v1_genomic
# selectiv5 	selectiv3
# GCA_009764365.1_L._kimchii_genomic
# selectiv5 	selectiv3
# GCA_007989125.1_ASM798912v1_genomic
# selectiv5 	selectiv3
# GCA_002706425.1_ASM270642v1_genomic
# selectiv5 	selectiv3
# GCA_001543205.1_ASM154320v1_genomic
# selectiv5 	selectiv3
# GCA_000745125.1_ASM74512v1_genomic
# selectiv5 	selectiv3
# GCA_000241055.1_ASM24105v1_genomic
# selectiv5 	selectiv3
# GCA_000425865.1_ASM42586v1_genomic
# selectiv5 	selectiv3
# GCA_000498955.1_DSM-21115_genomic
# selectiv5 	selectiv3
# GCA_900476045.1_50279_D01_genomic
# selectiv5 	selectiv3
# GCA_000196555.1_ASM19655v1_genomic
# selectiv5 	selectiv3
# GCA_019655995.1_ASM1965599v1_genomic
# selectiv5 	selectiv3
# GCA_002907375.1_ASM290737v1_genomic
# selectiv5 	selectiv3
# GCA_002259605.1_ASM225960v1_genomic
# selectiv5 	selectiv3
# GCA_000024285.1_ASM2428v1_genomic
# selectiv5 	selectiv3
# GCA_001039045.1_ASM103904v1_genomic
# selectiv5 	selectiv3
# GCA_000426405.1_ASM42640v1_genomic
# selectiv5 	selectiv3
# GCA_017086525.1_ASM1708652v1_genomic
# selectiv5 	selectiv3
# GCA_000831645.1_ASM83164v1_genomic
# selectiv5 	selectiv3
# GCA_000196855.1_ASM19685v1_genomic
# selectiv5 	selectiv3
# GCA_905371965.1_SRR9217392-mag-bin.15_genomic
# selectiv5 	selectiv3
# GCA_900478165.1_48290_A02_genomic
# selectiv5 	selectiv3
# GCA_004322755.1_ASM432275v1_genomic
# selectiv5 	selectiv3
# GCA_023657365.1_ASM2365736v1_genomic
# selectiv5 	selectiv3
# GCA_001436135.1_ASM143613v1_genomic
# selectiv5 	selectiv3
# GCA_017654245.1_ASM1765424v1_genomic
# selectiv5 	selectiv3
# GCA_014191315.1_ASM1419131v1_genomic
# selectiv5 	selectiv3
# GCA_000706765.1_ASM70676v1_genomic
# selectiv5 	selectiv3
# GCA_000615205.1_ASM61520v1_genomic
# selectiv5 	selectiv3
# GCA_002777965.1_ASM277796v1_genomic
# selectiv5 	selectiv3
# GCA_001025195.1_ASM102519v1_genomic
# selectiv5 	selectiv3
# GCA_900637095.1_48450_G02_genomic
# selectiv5 	selectiv3
# GCA_007989185.1_ASM798918v1_genomic
# selectiv5 	selectiv3
# GCA_000970855.1_ASM97085v1_genomic
# selectiv5 	selectiv3
# GCA_003795105.1_ASM379510v1_genomic
# selectiv5 	selectiv3
# GCA_002736025.1_ASM273602v1_genomic
# selectiv5 	selectiv3
# GCA_905371805.1_SRR9217392-mag-bin.4_genomic
# selectiv5 	selectiv3
# GCA_001591685.1_ASM159168v1_genomic
# selectiv5 	selectiv3
# GCA_000615725.1_ASM61572v1_genomic
# selectiv5 	selectiv3
# GCA_900103655.1_IMG-taxon_2597490363_annotated_assembly_genomic
# selectiv5 	selectiv3
# GCA_001311505.1_ASM131150v1_genomic
# selectiv5 	selectiv3
# GCA_900187315.1_52087_C01_genomic
# selectiv5 	selectiv3
# GCA_002811195.1_ASM281119v1_genomic
# selectiv5 	selectiv3
# GCA_001891125.1_ASM189112v1_genomic
# selectiv5 	selectiv3
# GCA_000771085.1_DSM-19703_genomic
# selectiv5 	selectiv3
# GCA_002706745.1_ASM270674v1_genomic
# selectiv5 	selectiv3
# GCA_001311525.1_ASM131152v1_genomic
# selectiv5 	selectiv3
# GCA_019655915.1_ASM1965591v1_genomic
# selectiv5 	selectiv3
# GCA_007990855.1_ASM799085v1_genomic
# selectiv5 	selectiv3
# GCA_900187015.1_50465_F01_genomic
# selectiv5 	selectiv3
# GCA_003946275.1_ASM394627v1_genomic
# selectiv5 	selectiv3
# GCA_005405645.1_ASM540564v1_genomic
# selectiv5 	selectiv3
# GCA_003641185.1_ASM364118v1_genomic
# selectiv5 	selectiv3
# GCA_003423665.1_ASM342366v1_genomic
# selectiv5 	selectiv3
# GCA_002706665.1_ASM270666v1_genomic
# selectiv5 	selectiv3
# GCA_019655935.1_ASM1965593v1_genomic
# selectiv5 	selectiv3
# GCA_007991295.1_ASM799129v1_genomic
# selectiv5 	selectiv3
# GCA_018717645.1_ASM1871764v1_genomic
# selectiv5 	selectiv3
# GCA_014646835.1_ASM1464683v1_genomic
# selectiv5 	selectiv3
# GCA_014467235.1_ASM1446723v1_genomic
# selectiv5 	selectiv3
# GCA_000020425.1_ASM2042v1_genomic
# selectiv5 	selectiv3
# GCA_001465545.1_ASM146554v1_genomic
# selectiv5 	selectiv3
# GCA_019753765.1_ASM1975376v1_genomic
# selectiv5 	selectiv3
# GCA_001047695.1_ASM104769v1_genomic
# selectiv5 	selectiv3
# GCA_900324475.1_EB-247_genomic
# selectiv5 	selectiv3
# GCA_002916915.1_ASM291691v1_genomic
# selectiv5 	selectiv3
# GCA_900637145.1_49569_E01_genomic
# selectiv5 	selectiv3
# GCA_000737845.1_BBOMBassembly_genomic
# selectiv5 	selectiv3
# GCA_000615405.1_ASM61540v1_genomic
# selectiv5 	selectiv3
# GCA_016908275.1_ASM1690827v1_genomic
# selectiv5 	selectiv3
# GCA_009764355.1_ASM976435v1_genomic
# selectiv5 	selectiv3
# GCA_001042675.1_ASM104267v1_genomic
# selectiv5 	selectiv3
# GCA_016908715.1_ASM1690871v1_genomic
# selectiv5 	selectiv3
# GCA_000876205.1_ASM87620v1_genomic
# selectiv5 	selectiv3
# GCA_000160855.1_ASM16085v1_genomic
# selectiv5 	selectiv3
# GCA_008326545.1_ASM832654v1_genomic
# selectiv5 	selectiv3
# GCA_001591885.1_ASM159188v1_genomic
# selectiv5 	selectiv3
# GCA_014635685.1_ASM1463568v1_genomic
# selectiv5 	selectiv3
# GCA_003946015.1_ASM394601v1_genomic
# selectiv5 	selectiv3
# GCA_005405505.1_ASM540550v1_genomic
# selectiv5 	selectiv3
# GCA_001888925.1_ASM188892v1_genomic
# selectiv5 	selectiv3
# GCA_000829035.1_ASM82903v1_genomic
# selectiv5 	selectiv3
# GCA_007992275.1_ASM799227v1_genomic
# selectiv5 	selectiv3
# GCA_002259755.1_ASM225975v1_genomic
# selectiv5 	selectiv3
# GCA_902833925.1_ASM90283392v1_genomic
# selectiv5 	selectiv3
# GCA_001936335.1_ASM193633v1_genomic
# selectiv5 	selectiv3
# GCA_900099625.1_IMG-taxon_2597490350_annotated_assembly_genomic
# selectiv5 	selectiv3
# GCA_000014445.1_ASM1444v1_genomic
# selectiv5 	selectiv3
# GCA_000010425.1_ASM1042v1_genomic
# selectiv5 	selectiv3
# GCA_000427785.1_ASM42778v1_genomic
# selectiv5 	selectiv3
# GCA_000014425.1_ASM1442v1_genomic
# selectiv5 	selectiv3
# GCA_900103055.1_IMG-taxon_2636416037_annotated_assembly_genomic
# selectiv5 	selectiv3
# GCA_001050115.1_ASM105011v1_genomic
# selectiv5 	selectiv3
# GCA_002802875.1_Spades_TRE1_genomic
# selectiv5 	selectiv3
# GCA_019443985.1_ASM1944398v1_genomic
# selectiv5 	selectiv3
# GCA_900637215.1_49888_B01_genomic
# selectiv5 	selectiv3
# GCA_002095475.1_ASM209547v1_genomic
# selectiv5 	selectiv3
# GCA_000829055.1_ASM82905v1_genomic
# selectiv5 	selectiv3
# GCA_007991995.1_ASM799199v1_genomic
# selectiv5 	selectiv3
# GCA_002259705.1_ASM225970v1_genomic
# selectiv5 	selectiv3
# GCA_002849895.1_ASM284989v1_genomic
# selectiv5 	selectiv3
# GCA_001592085.1_ASM159208v1_genomic
# selectiv5 	selectiv3
# GCA_007990205.1_ASM799020v1_genomic
# selectiv5 	selectiv3
# GCA_001311335.1_ASM131133v1_genomic
# selectiv5 	selectiv3
# GCA_012396505.1_ASM1239650v1_genomic
# selectiv5 	selectiv3
# GCA_900187025.1_49923_F01_genomic
# selectiv5 	selectiv3
# GCA_004209755.1_ASM420975v1_genomic
# selectiv5 	selectiv3
# GCA_000469365.1_ASM46936v1_genomic
# selectiv5 	selectiv3
# GCA_018094625.1_ASM1809462v1_genomic
# selectiv5 	selectiv3
# GCA_017299435.1_ASM1729943v1_genomic
# selectiv5 	selectiv3
# GCA_007989145.1_ASM798914v1_genomic
# selectiv5 	selectiv3
# GCA_900089835.1_VthalassaeCECT8203_Velvet_Prokka_genomic
# selectiv5 	selectiv3
# GCA_000423725.1_ASM42372v1_genomic
# selectiv5 	selectiv3
# GCA_002259645.1_ASM225964v1_genomic
# selectiv5 	selectiv3
# GCA_019656055.1_ASM1965605v1_genomic
# selectiv5 	selectiv3
# GCA_012103035.1_O.oryzae_NBRC_102588.fasta_genomic
# selectiv5 	selectiv3
# GCA_001025155.1_ASM102515v1_genomic
# selectiv5 	selectiv3
# GCA_007992315.1_ASM799231v1_genomic
# selectiv5 	selectiv3
# GCA_001313225.1_ASM131322v1_genomic
# selectiv5 	selectiv3
# GCA_010120595.1_ASM1012059v1_genomic
# selectiv5 	selectiv3
# GCA_017874575.1_ASM1787457v1_genomic
# selectiv5 	selectiv3
# GCA_009299505.1_ASM929950v1_genomic
# selectiv5 	selectiv3
# GCA_018987235.1_ASM1898723v1_genomic
# selectiv5 	selectiv3
# GCA_001908415.1_ASM190841v1_genomic
# selectiv5 	selectiv3
# GCA_000423745.1_ASM42374v1_genomic
# selectiv5 	selectiv3
# GCA_000296855.1_ASM29685v1_genomic
# selectiv5 	selectiv3
# GCA_001437255.1_ASM143725v1_genomic
# selectiv5 	selectiv3
# GCA_002907365.1_ASM290736v1_genomic
# selectiv5 	selectiv3
# GCA_900167245.1_IMG-taxon_2568526012_annotated_assembly_genomic
# selectiv5 	selectiv3
# GCA_014651235.1_ASM1465123v1_genomic
# selectiv5 	selectiv3
# GCA_007989165.1_ASM798916v1_genomic
# selectiv5 	selectiv3
# GCA_005405385.1_ASM540538v1_genomic
# selectiv5 	selectiv3
# GCA_001025175.1_ASM102517v1_genomic
# selectiv5 	selectiv3
# GCA_014898175.1_ASM1489817v1_genomic
# selectiv5 	selectiv3
# GCA_014651415.1_ASM1465141v1_genomic
# selectiv5 	selectiv3
# GCA_003946245.1_ASM394624v1_genomic
# selectiv5 	selectiv3
# GCA_001908495.1_ASM190849v1_genomic
# selectiv5 	selectiv3
# GCA_900079995.1_ASM90007999v1_genomic
# selectiv5 	selectiv3
# GCA_002706705.1_ASM270670v1_genomic
# selectiv5 	selectiv3
# GCA_002217925.1_ASM221792v1_genomic
# selectiv5 	selectiv3
# GCA_001433985.1_ASM143398v1_genomic
# selectiv5 	selectiv3
# GCA_000374385.1_ASM37438v1_genomic
# selectiv5 	selectiv3
# GCA_007991875.1_ASM799187v1_genomic
# selectiv5 	selectiv3
# GCA_000771045.1_DSM-17755_genomic
# selectiv5 	selectiv3
# GCA_017132775.1_ASM1713277v1_genomic
# selectiv5 	selectiv3
# GCA_014651255.1_ASM1465125v1_genomic
# selectiv5 	selectiv3
# GCA_000615245.1_ASM61524v1_genomic
# selectiv5 	selectiv3
# GCA_001434175.1_ASM143417v1_genomic
# selectiv5 	selectiv3
# GCA_000269965.1_ASM26996v1_genomic
# selectiv5 	selectiv3
# GCA_018314255.1_ASM1831425v1_genomic
# selectiv5 	selectiv3
# GCA_001025215.1_ASM102521v1_genomic
# selectiv5 	selectiv3
# GCA_014207505.1_ASM1420750v1_genomic
# selectiv5 	selectiv3
# GCA_901212485.1_NZ_Bifidobacterium_bifidum_MC1_genomic
# selectiv5 	selectiv3
# GCA_000016825.1_ASM1682v1_genomic
# selectiv5 	selectiv3
# GCA_003096575.1_ASM309657v1_genomic
# selectiv5 	selectiv3
# GCA_007991855.1_ASM799185v1_genomic
# selectiv5 	selectiv3
# GCA_000829395.1_ASM82939v1_genomic
# selectiv5 	selectiv3
# GCA_000010005.1_ASM1000v1_genomic
# selectiv5 	selectiv3
# GCA_015698225.1_ASM1569822v1_genomic
# selectiv5 	selectiv3
# GCA_013394085.1_ASM1339408v1_genomic
# selectiv5 	selectiv3
# GCA_014635905.1_ASM1463590v1_genomic
# selectiv5 	selectiv3
# GCA_002706375.1_ASM270637v1_genomic
# selectiv5 	selectiv3
# GCA_001311115.1_ASM131111v1_genomic
# selectiv5 	selectiv3
# GCA_001437285.1_ASM143728v1_genomic
# selectiv5 	selectiv3
# GCA_003369815.1_ASM336981v1_genomic
# selectiv5 	selectiv3
# GCA_004362535.1_ASM436253v1_genomic
# selectiv5 	selectiv3
# GCA_001281175.1_ASM128117v1_genomic
# selectiv5 	selectiv3
# GCA_001436025.1_ASM143602v1_genomic
# selectiv5 	selectiv3
# GCA_001042635.1_ASM104263v1_genomic
# selectiv5 	selectiv3
# GCA_000185065.2_ASM18506v1_genomic
# selectiv5 	selectiv3
# GCA_900186835.1_49950_F01_genomic
# selectiv5 	selectiv3
# GCA_000429585.1_ASM42958v1_genomic
# selectiv5 	selectiv3
# GCA_019656015.1_ASM1965601v1_genomic
# selectiv5 	selectiv3
# GCA_017298735.1_ASM1729873v1_genomic
# selectiv5 	selectiv3
# GCA_001047135.1_ASM104713v1_genomic
# selectiv5 	selectiv3
# GCA_000632805.1_ASM63280v1_genomic
# selectiv5 	selectiv3
# GCA_000056065.1_ASM5606v1_genomic
# selectiv5 	selectiv3
# GCA_002278095.1_ASM227809v1_genomic
# selectiv5 	selectiv3
# GCA_009299485.1_ASM929948v1_genomic
# selectiv5 	selectiv3
# GCA_003697165.1_ASM369716v1_genomic
# selectiv5 	selectiv3
# GCA_900637175.1_49569_F01_genomic
# selectiv5 	selectiv3
# GCA_000166715.2_ASM16671v1_genomic
# selectiv5 	selectiv3
# GCA_001042615.1_ASM104261v1_genomic
# selectiv5 	selectiv3
# GCA_900637335.1_50618_H02_genomic
# selectiv5 	selectiv3
# GCA_007991135.1_ASM799113v1_genomic
# selectiv5 	selectiv3
# GCA_017132755.1_ASM1713275v1_genomic
# selectiv5 	selectiv3
# GCA_000260715.1_ASM26071v1_genomic
# selectiv5 	selectiv3
# GCA_000744255.1_ASM74425v1_genomic
# selectiv5 	selectiv3
# GCA_004101845.1_ASM410184v1_genomic
# selectiv5 	selectiv3
# GCA_003047065.1_ASM304706v1_genomic
# selectiv5 	selectiv3
# GCA_000143745.1_ASM14374v1_genomic
# selectiv5 	selectiv3
# GCA_009764345.1_ASM976434v1_genomic
# selectiv5 	selectiv3
# GCA_014651435.1_ASM1465143v1_genomic
# selectiv5 	selectiv3
# GCA_002607735.1_ASM260773v1_genomic
# selectiv5 	selectiv3
# GCA_014898155.1_ASM1489815v1_genomic
# selectiv5 	selectiv3
# GCA_002015125.1_ASM201512v1_genomic
# selectiv5 	selectiv3
# GCA_001042695.1_ASM104269v1_genomic
# selectiv5 	selectiv3
# GCA_000146325.1_ASM14632v1_genomic
# selectiv5 	selectiv3
# GCA_009727155.1_ASM972715v1_genomic
# selectiv5 	selectiv3
# GCA_002259745.1_ASM225974v1_genomic
# selectiv5 	selectiv3
# GCA_000615325.1_ASM61532v1_genomic
# selectiv5 	selectiv3
# GCA_014651215.1_ASM1465121v1_genomic
# selectiv5 	selectiv3
# GCA_019586025.1_ASM1958602v1_genomic
# selectiv5 	selectiv3
# GCA_009495475.1_ASM949547v1_genomic
# selectiv5 	selectiv3
# GCA_020089505.1_ASM2008950v1_genomic
# selectiv5 	selectiv3
# GCA_001263395.1_ASM126339v1_genomic
# selectiv5 	selectiv3
# GCA_900015005.1_Lactobacillus_oligofermentans_LMG_22743_genome_genomic
# selectiv5 	selectiv3
# GCA_003641145.1_ASM364114v1_genomic
# selectiv5 	selectiv3
# GCA_000967195.1_ASM96719v1_genomic
# selectiv5 	selectiv3
# GCA_014634745.1_ASM1463474v1_genomic
# selectiv5 	selectiv3
# GCA_001436735.1_ASM143673v1_genomic
# selectiv5 	selectiv3
# GCA_007992235.1_ASM799223v1_genomic
# selectiv5 	selectiv3
# GCA_019444005.1_ASM1944400v1_genomic
# selectiv5 	selectiv3
# GCA_014648715.1_ASM1464871v1_genomic
# selectiv5 	selectiv3
# GCA_000163475.1_ASM16347v1_genomic
# selectiv5 	selectiv3
# GCA_014131735.1_ASM1413173v1_genomic
# selectiv5 	selectiv3
# GCA_000008565.1_ASM856v1_genomic
# selectiv5 	selectiv3
# GCA_001274725.1_ASM127472v1_genomic
# selectiv5 	selectiv3
# GCA_019656075.1_ASM1965607v1_genomic
# selectiv5 	selectiv3
# GCA_003641165.1_ASM364116v1_genomic
# selectiv5 	selectiv3
# GCA_001888965.1_ASM188896v1_genomic
# selectiv5 	selectiv3
# GCA_009299475.1_ASM929947v1_genomic
# selectiv5 	selectiv3
# GCA_000744825.1_ASM74482v1_genomic
# selectiv5 	selectiv3
# GCA_002370355.1_ASM237035v1_genomic
# selectiv5 	selectiv3
# 1423804.4
# selectiv5 	selectiv3
# 348151.3
# selectiv5 	selectiv3
# 1121112.3
# selectiv5 	selectiv3
# 941770.3
# selectiv5 	selectiv3
# 525327.3
# selectiv5 	selectiv3
# 1423748.3
# selectiv5 	selectiv3
# 566552.18
# selectiv5 	selectiv3
# 1236940.3
# selectiv5 	selectiv3
# 1122147.4
# selectiv5 	selectiv3
# 1217420.3
# selectiv5 	selectiv3
# 1423791.3
# selectiv5 	selectiv3
# 1423736.4
# selectiv5 	selectiv3
# 1437600.3
# selectiv5 	selectiv3
# 1423797.16
# selectiv5 	selectiv3
# 367928.6
# selectiv5 	selectiv3
# 649758.3
# selectiv5 	selectiv3
# 1046597.4
# selectiv5 	selectiv3
# 1437606.5
# selectiv5 	selectiv3
# 1423820.4
# selectiv5 	selectiv3
# 375175.92
# selectiv5 	selectiv3
# 1423797.7
# selectiv5 	selectiv3
# 1236534.3
# selectiv5 	selectiv3
# 1423753.3
# selectiv5 	selectiv3
# 561180.4
# selectiv5 	selectiv3
# 1423800.3
# selectiv5 	selectiv3
# 1293592.9
# selectiv5 	selectiv3
# 987066.3
# selectiv5 	selectiv3
# 1121109.3
# selectiv5 	selectiv3
# 1223498.3
# selectiv5 	selectiv3
# 47770.64
# selectiv5 	selectiv3
# 525325.3
# selectiv5 	selectiv3
# 1423768.4
# selectiv5 	selectiv3
# 1423777.3
# selectiv5 	selectiv3
# 1423819.3
# selectiv5 	selectiv3
# 1203066.3
# selectiv5 	selectiv3
# 872328.3
# selectiv5 	selectiv3
# 525364.3
# selectiv5 	selectiv3
# 649758.4
# selectiv5 	selectiv3
# 525328.13
# selectiv5 	selectiv3
# 1423736.3
# selectiv5 	selectiv3
# 1423773.3
# selectiv5 	selectiv3
# 525338.16
# selectiv5 	selectiv3
# 1423802.4
# selectiv5 	selectiv3
# 525338.3
# selectiv5 	selectiv3
# 1122147.3
# selectiv5 	selectiv3
# 1423757.3
# selectiv5 	selectiv3
# 1423723.12
# selectiv5 	selectiv3
# 321983.3
# selectiv5 	selectiv3
# 942150.3
# selectiv5 	selectiv3
# 391904.5
# selectiv5 	selectiv3
# 1423730.4
# selectiv5 	selectiv3
# 1423775.4
# selectiv5 	selectiv3
# 941770.4
# selectiv5 	selectiv3
# 1620.3
# selectiv5 	selectiv3
# 1423732.4
# selectiv5 	selectiv3
# 1293598.4
# selectiv5 	selectiv3
# 1423768.3
# selectiv5 	selectiv3
# 1423806.3
# selectiv5 	selectiv3
# 216816.128
# selectiv5 	selectiv3
# 762211.3
# selectiv5 	selectiv3
# 187452.24
# selectiv5 	selectiv3
# 1236942.4
# selectiv5 	selectiv3
# 1423734.3
# selectiv5 	selectiv3
# 1423771.3
# selectiv5 	selectiv3
# 566552.4
# selectiv5 	selectiv3
# 1226675.3
# selectiv5 	selectiv3
# 219334.4
# selectiv5 	selectiv3
# 525366.3
# selectiv5 	selectiv3
# 1395513.3
# selectiv5 	selectiv3
# 1255.112
# selectiv5 	selectiv3
# 1689.18
# selectiv5 	selectiv3
# 1123358.5
# selectiv5 	selectiv3
# 1114972.5
# selectiv5 	selectiv3
# 1423792.3
# selectiv5 	selectiv3
# 1291734.4
# selectiv5 	selectiv3
# 1046596.6
# selectiv5 	selectiv3
# 1423752.3
# selectiv5 	selectiv3
# 1423717.3
# selectiv5 	selectiv3
# 1423823.4
# selectiv5 	selectiv3
# 1590.1803
# selectiv5 	selectiv3
# 219334.11
# selectiv5 	selectiv3
# 500634.6
# selectiv5 	selectiv3
# 1423776.3
# selectiv5 	selectiv3
# 1150460.3
# selectiv5 	selectiv3
# 585520.12
# selectiv5 	selectiv3
# 1588.22
# selectiv5 	selectiv3
# 1423769.4
# selectiv5 	selectiv3
# 881260.84
# selectiv5 	selectiv3
# 585524.9
# selectiv5 	selectiv3
# 1236943.3
# selectiv5 	selectiv3
# 888027.3
# selectiv5 	selectiv3
# 1587.663
# selectiv5 	selectiv3
# 1114972.6
# selectiv5 	selectiv3
# 1423749.3
# selectiv5 	selectiv3
# 1236941.3
# selectiv5 	selectiv3
# 930942.3
# selectiv5 	selectiv3
# 1236939.3
# selectiv5 	selectiv3
# 1423789.3
# selectiv5 	selectiv3
# 1423774.3
# selectiv5 	selectiv3
# 1423731.3
# selectiv5 	selectiv3
# 1423805.4
# selectiv5 	selectiv3
# 33965.25
# selectiv5 	selectiv3
# 1423750.3
# selectiv5 	selectiv3
# 1423715.3
# selectiv5 	selectiv3
# 500634.4
# selectiv5 	selectiv3
# 1046596.4
# selectiv5 	selectiv3
# 1423821.4
# selectiv5 	selectiv3
# 1423790.3
# selectiv5 	selectiv3
# 1423728.3
# selectiv5 	selectiv3
# 1133569.4
# selectiv5 	selectiv3
# 396598.11
# selectiv5 	selectiv3
# 616990.3
# selectiv5 	selectiv3
# 1423807.3
# selectiv5 	selectiv3
# 1423717.5
# selectiv5 	selectiv3
# 1423794.3
# selectiv5 	selectiv3
# 1358.88
# selectiv5 	selectiv3
# 1423776.4
# selectiv5 	selectiv3
# 1423733.4
# selectiv5 	selectiv3
# 1423823.3
# selectiv5 	selectiv3
# 1226298.3
# selectiv5 	selectiv3
# 1579.22
# selectiv5 	selectiv3
# 1291734.3
# selectiv5 	selectiv3
# 1348632.3
# selectiv5 	selectiv3
# 1423801.4
# selectiv5 	selectiv3
# 324831.46
# selectiv5 	selectiv3
# 1437603.4
# selectiv5 	selectiv3
# 907931.3
# selectiv5 	selectiv3
# 1329411.4
# selectiv5 	selectiv3
# 83683.14
# selectiv5 	selectiv3
# 1590.625
# selectiv5 	selectiv3
# 525365.3
# selectiv5 	selectiv3
# 33966.4
# selectiv5 	selectiv3
# 1150460.13
# selectiv5 	selectiv3
# 500634.3
# selectiv5 	selectiv3
# 1267156.3
# selectiv5 	selectiv3
# 585520.17
# selectiv5 	selectiv3
# 45462.11
# selectiv5 	selectiv3
# 1437607.3
# selectiv5 	selectiv3
# 888027.6
# selectiv5 	selectiv3
# 157463.3
# selectiv5 	selectiv3
# 1423745.4
# selectiv5 	selectiv3
# 1629.5
# selectiv5 	selectiv3
# 1236952.3
# selectiv5 	selectiv3
# 1423814.6
# selectiv5 	selectiv3
# 913848.3
# selectiv5 	selectiv3
# 1423722.3
# selectiv5 	selectiv3
# 179838.8
# selectiv5 	selectiv3
# 1423767.3
# selectiv5 	selectiv3
# 1236545.3
# selectiv5 	selectiv3
# 1349780.3
# selectiv5 	selectiv3
# 1423809.3
# selectiv5 	selectiv3
# 1423778.4
# selectiv5 	selectiv3
# 1423785.4
# selectiv5 	selectiv3
# 396598.3
# selectiv5 	selectiv3
# 1218173.3
# selectiv5 	selectiv3
# 586220.3
# selectiv5 	selectiv3
# 33966.9
# selectiv5 	selectiv3
# 585520.4
# selectiv5 	selectiv3
# 1437596.3
# selectiv5 	selectiv3
# 1423719.4
# selectiv5 	selectiv3
# 1423724.4
# selectiv5 	selectiv3
# 557436.17
# selectiv5 	selectiv3
# 1437610.3
# selectiv5 	selectiv3
# 888027.8
# selectiv5 	selectiv3
# 83684.12
# selectiv5 	selectiv3
# 1423739.3
# selectiv5 	selectiv3
# 1423812.3
# selectiv5 	selectiv3
# 1122228.3
# selectiv5 	selectiv3
# 1131731.3
# selectiv5 	selectiv3
# 872327.3
# selectiv5 	selectiv3
# 1583.306
# selectiv5 	selectiv3
# 1423720.3
# selectiv5 	selectiv3
# 547043.6
# selectiv5 	selectiv3
# 1585.83
# selectiv5 	selectiv3
# 1423798.3
# selectiv5 	selectiv3
# 1437609.3
# selectiv5 	selectiv3
# 862514.3
# selectiv5 	selectiv3
# 1505727.12
# selectiv5 	selectiv3
# 525328.4
# selectiv5 	selectiv3
# 203120.23
# selectiv5 	selectiv3
# 542833.3
# selectiv5 	selectiv3
# 1236950.3
# selectiv5 	selectiv3
# 1255.195
# selectiv5 	selectiv3
# 585524.3
# selectiv5 	selectiv3
# 1341694.4
# selectiv5 	selectiv3
# 525337.3
# selectiv5 	selectiv3
# 54911.3
# selectiv5 	selectiv3
# 1423761.3
# selectiv5 	selectiv3
# 337330.69
# selectiv5 	selectiv3
# 557436.4
# selectiv5 	selectiv3
# 1211775.3
# selectiv5 	selectiv3
# 1122153.4
# selectiv5 	selectiv3
# 1423743.5
# selectiv5 	selectiv3
# 1423785.3
# selectiv5 	selectiv3
# 1423816.3
# selectiv5 	selectiv3
# 390333.7
# selectiv5 	selectiv3
# 518634.7
# selectiv5 	selectiv3
# 555970.3
# selectiv5 	selectiv3
# 1122148.6
# selectiv5 	selectiv3
# 390333.13
# selectiv5 	selectiv3
# 1123687.3
# selectiv5 	selectiv3
# 1423829.3
# selectiv5 	selectiv3
# 1423747.3
# selectiv5 	selectiv3
# 1435051.3
# selectiv5 	selectiv3
# 585506.3
# selectiv5 	selectiv3
# 1423798.4
# selectiv5 	selectiv3
# 203120.7
# selectiv5 	selectiv3
# 525367.9
# selectiv5 	selectiv3
# 1255.14
# selectiv5 	selectiv3
# 1226298.9
# selectiv5 	selectiv3
# 1616.3
# selectiv5 	selectiv3
# 913848.7
# selectiv5 	selectiv3
# 1423781.4
# selectiv5 	selectiv3
# 1291764.5
# selectiv5 	selectiv3
# 993692.3
# selectiv5 	selectiv3
# 33962.8
# selectiv5 	selectiv3
# 390333.12
# selectiv5 	selectiv3
# 1423726.3
# selectiv5 	selectiv3
# 1435464.3
# selectiv5 	selectiv3
# 1450649.3
# selectiv5 	selectiv3
# 1437595.3
# selectiv5 	selectiv3
# 1423833.6
# selectiv5 	selectiv3
# 82380.43
# selectiv5 	selectiv3
# 1423738.3
# selectiv5 	selectiv3
# 1462575.3
# selectiv5 	selectiv3
# 47770.84
# selectiv5 	selectiv3
# 1437611.3
# selectiv5 	selectiv3
# 1494462.5
# selectiv5 	selectiv3
# 1341695.4
# selectiv5 	selectiv3
# 557433.4
# selectiv5 	selectiv3
# 1122149.3
# selectiv5 	selectiv3
# 47770.576
# selectiv5 	selectiv3
# 1423786.4
# selectiv5 	selectiv3
# 46256.17
# selectiv5 	selectiv3
# 1236546.3
# selectiv5 	selectiv3
# 1410645.4
# selectiv5 	selectiv3
# 1423799.3
# selectiv5 	selectiv3
# 525330.7
# selectiv5 	selectiv3
# 518634.21
# selectiv5 	selectiv3
# 1423784.4
# selectiv5 	selectiv3
# 1410647.4
# selectiv5 	selectiv3
# 1423833.5
# selectiv5 	selectiv3
# 391904.8
# selectiv5 	selectiv3
# 1423744.4
# selectiv5 	selectiv3
# 1423782.3
# selectiv5 	selectiv3
# 1629.13
# selectiv5 	selectiv3
# 480391.6
# selectiv5 	selectiv3
# 1578.21
# selectiv5 	selectiv3
# 1423764.4
# selectiv5 	selectiv3
# 1423721.4
# selectiv5 	selectiv3
# 1423815.3
# selectiv5 	selectiv3
# 1437608.4
# selectiv5 	selectiv3
# 1293592.5
# selectiv5 	selectiv3
# 566552.17
# selectiv5 	selectiv3
# 1423746.3
# selectiv5 	selectiv3
# 703613.4
# selectiv5 	selectiv3
# 1423762.3
# selectiv5 	selectiv3
# 1423727.3
# selectiv5 	selectiv3
# 137591.149
# selectiv5 	selectiv3
# 1423780.4
# selectiv5 	selectiv3
# 566552.16
# selectiv5 	selectiv3
# 1624.128
# selectiv5 	selectiv3
# 1423764.5
# selectiv5 	selectiv3
# 518634.19
# selectiv5 	selectiv3
# 525330.3
# selectiv5 	selectiv3
# 1255.124
# selectiv5 	selectiv3
# 1045004.5
# selectiv5 	selectiv3
# 218139.4
# selectiv5 	selectiv3
# 109790.239
# selectiv5 	selectiv3
# 1423742.4
# selectiv5 	selectiv3
# 1423833.3
# selectiv5 	selectiv3
# 1423718.3
# selectiv5 	selectiv3
# 1121107.3
# selectiv5 	selectiv3
# 1423760.3
# selectiv5 	selectiv3
# 1423782.4
# selectiv5 	selectiv3
# 1220560.3
# selectiv5 	selectiv3
# 1423766.4
# selectiv5 	selectiv3
# 518635.7
# selectiv5 	selectiv3
# 372484.4
# selectiv5 	selectiv3
# 1410647.3
# selectiv5 	selectiv3
# 324831.13
# selectiv5 	selectiv3
# 1423779.3
# selectiv5 	selectiv3
# 1423817.3
# selectiv5 	selectiv3
# 1680.108
# selectiv5 	selectiv3
